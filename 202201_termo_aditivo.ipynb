# %%
import pandas as pd
df_termos = pd.read_csv('202201_TermoAditivo.csv', sep=';', encoding='cp1252')

# %%
df_termos.sort_values(by=['Número Termo Aditivo']).head(15)
# Out:
#      Número Contrato  Código Órgão Superior          Nome Órgão Superior  \
# 493            22022                  25000       Ministério da Economia
# 51             42011                  41000  Ministério das Comunicações
# 515            42010                  25000       Ministério da Economia
# 41            182012                  41000  Ministério das Comunicações
# 516            42010                  25000       Ministério da Economia
# 35            112013                  41000  Ministério das Comunicações
# 47            342012                  41000  Ministério das Comunicações
# 517            42010                  25000       Ministério da Economia
# 518            42010                  25000       Ministério da Economia
# 519            42010                  25000       Ministério da Economia
# 380            32016                  26000       Ministério da Educação
# 520            42010                  25000       Ministério da Economia
# 686           682017                  52000         Ministério da Defesa
# 521            42010                  25000       Ministério da Economia
# 149           712017                  26000       Ministério da Educação
#
#      Código Órgão                                     Nome Órgão  Código UG  \
# 493         25000  Ministério da Economia - Unidades com vínculo     170010
# 51          20415                  Empresa Brasil de Comunicação     115406
# 515         25000  Ministério da Economia - Unidades com vínculo     170271
# 41          20415                  Empresa Brasil de Comunicação     115406
# 516         25000  Ministério da Economia - Unidades com vínculo     170271
# 35          20415                  Empresa Brasil de Comunicação     115406
# 47          20415                  Empresa Brasil de Comunicação     115406
# 517         25000  Ministério da Economia - Unidades com vínculo     170271
# 518         25000  Ministério da Economia - Unidades com vínculo     170271
# 519         25000  Ministério da Economia - Unidades com vínculo     170271
# 380         26438            Instituto Federal de Santa Catarina     158516
# 520         25000  Ministério da Economia - Unidades com vínculo     170271
# 686         52131                             Comando da Marinha     771100
# 521         25000  Ministério da Economia - Unidades com vínculo     170271
# 149         26242             Universidade Federal de Pernambuco     153080
#
#                                            Nome UG  Número Termo Aditivo  \
# 493   SECRETARIA ESP. DA RECEITA FEDERAL DO BRASIL                  2022
# 51               EMPRESA BRASIL DE COMUNICACAO S.A                 12011
# 515                     DELEGACIA DA RFB EM PALMAS                 12011
# 41               EMPRESA BRASIL DE COMUNICACAO S.A                 12012
# 516                     DELEGACIA DA RFB EM PALMAS                 12012
# 35               EMPRESA BRASIL DE COMUNICACAO S.A                 12012
# 47               EMPRESA BRASIL DE COMUNICACAO S.A                 12013
# 517                     DELEGACIA DA RFB EM PALMAS                 12013
# 518                     DELEGACIA DA RFB EM PALMAS                 12014
# 519                     DELEGACIA DA RFB EM PALMAS                 12015
# 380  INST.FED.DE EDUC.,CIENC.E TEC.DE STA.CAT/IFSC                 12016
# 520                     DELEGACIA DA RFB EM PALMAS                 12016
# 686  BASE DE ABASTEC. DA MARINHA NO RIO DE JANEIRO                 12017
# 521                     DELEGACIA DA RFB EM PALMAS                 12017
# 149             UNIVERSIDADE FEDERAL DE PERNAMBUCO                 12018
#
#     Data Publicação                                             Objeto
# 493      08/06/2022  Objetivo: PRORROGAÇÃO DA VALIDADE DA ATA DE RE...
# 51       27/04/2011  Objetivo: RERRATIFICAR O ANEXO I AO CONTRATO O...
# 515      27/01/2022  Objetivo: ALTERAÇÃO DA VIGÊNCIA DO CONTRATO OR...
# 41       28/01/2022  Objetivo: PRORROGAR O PRAZO DE VIGÊNCIA DO CON...
# 516      27/01/2022  Objetivo: ALTERAÇÃO DA VIGÊNCIA DO CONTRATO OR...
# 35       28/02/2014  Objetivo: PRORROGAR O PRAZO DE VIGÊNCIA E REGI...
# 47       02/08/2013  Objetivo: PRORROGAR O PRAZO DE VIGÊNCIA DO CON...
# 517      27/01/2022  Objetivo: ALTERAÇÃO DA VIGÊNCIA DO CONTRATO OR...
# 518      25/03/2022                  Objetivo: PRORROGAÇÃO DA VIGENCIA
# 519      25/03/2022                   Objetivo: PRORROGÇÃO DA VIGENCIA
# 380      13/01/2022  Objetivo: PRORROGAÇÃO CONTRATUAL REFERENTE AOS...
# 520      24/03/2022                  Objetivo: PRORROGAÇÃO DA VIGENCIA
# 686      31/01/2022  Objetivo: O PRESENTE TERMO ADITIVO, VISA A PRO...
# 521      25/03/2022                    Objetivo: RENOVAÇÃO DA VIGENCIA
# 149      25/01/2022  Objetivo: O PRESENTE TERMO ADITIVO TEM POR OBJ...

# %%
df_termos.head()
# Out:
#    Número Contrato  Código Órgão Superior       Nome Órgão Superior  \
# 0            32022                  20000  Presidência da República
# 1           132021                  63000  Advocacia-Geral da União
# 2           142021                  63000  Advocacia-Geral da União
# 3           142021                  63000  Advocacia-Geral da União
# 4           102022                  63000  Advocacia-Geral da União
#
#    Código Órgão                                     Nome Órgão  Código UG  \
# 0         20101                       Presidência da República     110001
# 1         63000  Advocacia-Geral da União - Unidades com víncu     110097
# 2         63000  Advocacia-Geral da União - Unidades com víncu     110097
# 3         63000  Advocacia-Geral da União - Unidades com víncu     110097
# 4         63000  Advocacia-Geral da União - Unidades com víncu     110099
#
#                                         Nome UG  Número Termo Aditivo  \
# 0       SECRETARIA ESPECIAL DE ADMINISTRACAO/PR                 12022
# 1  SUPERINTENDENCIA ADMINISTRACAO NO RIO G. SUL                 12022
# 2  SUPERINTENDENCIA ADMINISTRACAO NO RIO G. SUL                 12022
# 3  SUPERINTENDENCIA ADMINISTRACAO NO RIO G. SUL                 22022
# 4   SUPERINTENDENCIA ADMINISTRACAO EM SAO PAULO                 12022
#
#   Data Publicação                                             Objeto
# 0      11/10/2022                Objetivo: ACRÉSCIMO DE QUANTITATIVO
# 1      07/07/2022  Objetivo: ACRESCIMO DE QUANTITATIVOS DOS ITENS...
# 2      20/06/2022  Objetivo: ACRÉSCIMO DE QUANTITATIVOS DOS SUBIT...
# 3      23/08/2022  Objetivo: ADITIVO DE ACRESCIMO  NO VALOR DE R$...
# 4      04/11/2022  Objetivo: 1.1.O OBJETO DO PRESENTE INSTRUMENTO...

# %%
df_termos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Número Contrato        704 non-null    int64
#  1   Código Órgão Superior  704 non-null    int64
#  2   Nome Órgão Superior    704 non-null    object
#  3   Código Órgão           704 non-null    int64
#  4   Nome Órgão             704 non-null    object
#  5   Código UG              704 non-null    int64
#  6   Nome UG                704 non-null    object
#  7   Número Termo Aditivo   704 non-null    int64
#  8   Data Publicação        704 non-null    object
#  9   Objeto                 704 non-null    object
# dtypes: int64(5), object(5)
# memory usage: 55.1+ KB

# %%
# Aplicar uma função para percorrer todas as colunas, contar quantos caracteres temos em cada coluna de máximo para configurar o banco de dados
def max_string_length(df):
    max_lengths = {}
    for col in df:
        if df[col].dtype == 'object':  # verifica se o tipo da coluna é string
            max_lengths[col] = df[col].apply(lambda x: len(str(x))).max()  # aplica a função len() em cada valor da coluna e encontra o máximo
    return max_lengths

# %%
print(max_string_length(df_termos))  # imprimir as colunas:qtde maior de caracteres encontrada
# Out:
# {'Nome Órgão Superior': 45, 'Nome Órgão': 45, 'Nome UG': 45, 'Data Publicação': 10, 'Objeto': 517}
